# %% [markdown]
# <a href="https://colab.research.google.com/github/chodhitha03/AIML_2303A52039/blob/main/2303A52039(AIML1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PART 1 – Implement Basic Data Structures using Numpy, Pandas**

# %%
import numpy as np
lst1 = [2,4,6,8]
array1=[lst1]
array1
# Out:
# [[2, 4, 6, 8]]

# %%
import numpy as np
lst2=[1,3,5,7]
array2=np.array(lst2)
array2
# Out:
# array([1, 3, 5, 7])

# %%
type(array1)
# Out:
# list

# %%
type(array2)
# Out:
# numpy.ndarray

# %% [markdown]
# **Perform mathematical operations on these datasets created - multiplication, division,
# poweroff**

# %%
print(array1*array2)
# Out:
# [[ 2 12 30 56]]

# %%
print(array1/array2)
# Out:
# [[2.         1.33333333 1.2        1.14285714]]

# %%
print(array1**array2)
# Out:
# [[      2      64    7776 2097152]]

# %% [markdown]
# **Perform Mathematical Operations on these datasets - sin and log operation**

# %%
print("Sin: ",np.sin(array1))
print("Natural logarithm: ",np.log(array1))
print("Base-10 logarithm: ",np.log10(array1))
print("Base-2 logarithm: ",np.log2(array1))
print("Exponential: ",np.exp(array1))
# Out:
# Sin:  [[ 0.90929743 -0.7568025  -0.2794155   0.98935825]]
# Natural logarithm:  [[0.69314718 1.38629436 1.79175947 2.07944154]]
# Base-10 logarithm:  [[0.30103    0.60205999 0.77815125 0.90308999]]
# Base-2 logarithm:  [[1.        2.        2.5849625 3.       ]]
# Exponential:  [[   7.3890561    54.59815003  403.42879349 2980.95798704]]

# %%
print("Add two arrays:", array1+array2)
# Out:
# Add two arrays: [[ 3  7 11 15]]

# %% [markdown]
# **PART 2 -  Visualization of Data using matplotlib, pyplots Pack
# ages[CO2]**
#  1. Generate a Data set for Health Care using the following

# %%
import matplotlib.pyplot as plt

# %%
people= ["chodhitha","charvika","shivani","mahesh"]
age =[18,17,19,20]
height =[153,145,140,173]
weight=[42,40,45,57]

# %%
plt.scatter(weight,height)
plt.title("relation of height and weigth of the patients")
plt.xlabel("weight of patients in kg")
plt.ylabel("height in meters")
plt.show()

# %% [markdown]
# **Bar plot**

# %%
plt.figure(figsize=(13,6))
plt.title("weight in kgs",fontsize=20,fontstyle='oblique')
plt.bar(x=people,height=weight,width=0.3,color='pink',alpha=0.9)
plt.xlabel("people",fontsize=15)
plt.ylabel("weight in kgs",fontsize=15)
plt.xticks(fontsize=16)
plt.yticks(fontsize=18)
plt.show()

# %% [markdown]
# **HISTOGRAM**

# %%
plt.figure(figsize=(6,6))
plt.title("Histogram of patients weight",fontsize=16,fontstyle='oblique')
plt.hist(weight,color='green',edgecolor='k',alpha=0.7,bins=5)
plt.xlabel("weight in kgs",fontsize=15)
plt.xticks(fontsize=16)
plt.yticks(fontsize=18)
plt.show()

# %% [markdown]
# **PART-3** *ACCESSING DATA FROM VARIOUS SOURCES*

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **TEXT FILE**

# %%
data=pd.read_table("ai(1).txt")
data
# Out:
#   s.no name       age
# 0  1    Chodhitha  18
# 1  2    Charvika   18
# 2  3    Shivani    19
# 3  4    Sharanya   19

# %%
csv=pd.read_csv("/content/sample_data/california_housing_train.csv")
csv
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
tsv=pd.read_csv("/content/ai(1).txt",delimiter='\t')
tsv
# Out:
#   s.no name       age
# 0  1    Chodhitha  18
# 1  2    Charvika   18
# 2  3    Shivani    19
# 3  4    Sharanya   19

# %%
exel=pd.read_excel("/content/ai_1.xlsx")
exel
# Out:
#    SNO       NAME  PERCENTAGE
# 0    1  Chodhitha          79
# 1    2   Charvika          81
# 2    3   Sharanya          69
# 3    4    Shivani          82
